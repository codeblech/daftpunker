# %%
import os
import yt_dlp as youtube_dl
from googleapiclient.errors import HttpError
from googleapiclient.discovery import build
import pandas as pd

# Set up your YouTube Data API key
API_KEY = "AIzaSyD5h1myju5oxuNDA1XDUaIKy_piFUfEPIU"


def get_playlist_id(playlist_url):
    with youtube_dl.YoutubeDL() as ydl:
        info_dict = ydl.extract_info(playlist_url, download=False)
        return info_dict.get("id", "")


def get_video_ids_from_playlist(playlist_id, api_key):
    youtube = build("youtube", "v3", developerKey=api_key)
    request = youtube.playlistItems().list(
        part="contentDetails", playlistId=playlist_id, maxResults=50
    )
    response = request.execute()

    video_ids = [item["contentDetails"]["videoId"] for item in response["items"]]
    return video_ids


def youtube_video_info(video_id, api_key, playlist_url):
    youtube = build("youtube", "v3", developerKey=api_key)
    try:
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics", id=video_id
        )
        response = request.execute()

        video_info = {
            "title": response["items"][0]["snippet"]["title"]
            if "items" in response and response["items"]
            else "",
            "description": response["items"][0]["snippet"]["description"]
            if "items" in response and response["items"]
            else "",
            "duration": response["items"][0]["contentDetails"]["duration"]
            if "items" in response and response["items"]
            else "",
            "views": int(response["items"][0]["statistics"]["viewCount"])
            if "items" in response and response["items"]
            else 0,
            "genre": response["items"][0]["snippet"]["categoryId"]
            if "items" in response and response["items"]
            else "",
            "upload_date": response["items"][0]["snippet"]["publishedAt"]
            if "items" in response and response["items"]
            else "",
            "url": f"https://www.youtube.com/watch?v={video_id}",  # Add video URL
            "playlist_url": playlist_url,  # Add playlist URL
            # Add more details as needed
        }

        return video_info
    except HttpError as e:
        # Handle HttpError (video not available)
        print(f"Video with ID {video_id} is not available. Skipping.")
        return None


def create_playlist_dataframe(video_ids, api_key, playlist_url):
    video_info_list = []

    for video_id in video_ids:
        video_info = youtube_video_info(video_id, api_key, playlist_url)
        if video_info is not None:
            video_info_list.append(video_info)

    video_dataframe = pd.DataFrame(video_info_list)
    return video_dataframe

def main():
    # Example YouTube playlist URL
    youtube_playlist_url = "https://music.youtube.com/browse/VLPL465FyR4NKwpCsiV2DQIlwWkdeN2lZBzM"

    # Set up your YouTube Data API key
    api_key = "AIzaSyD5h1myju5oxuNDA1XDUaIKy_piFUfEPIU"

    # Get playlist ID and video IDs
    playlist_id = get_playlist_id(youtube_playlist_url)
    video_ids = get_video_ids_from_playlist(playlist_id, api_key)

    # Create a DataFrame with extracted features for the playlist videos
    playlist_dataframe = create_playlist_dataframe(video_ids, api_key, youtube_playlist_url)

    # Display the DataFrame
    print("\nDataFrame:")
    print(playlist_dataframe)

    # Save the DataFrame to a CSV file
    csv_file_path = "playlist_videos_new4.csv"
    playlist_dataframe.to_csv(csv_file_path, index=False)
    print(f"\nDataFrame saved to {csv_file_path}")


main()
# Out:
# [youtube:tab] Extracting URL: https://music.youtube.com/browse/VLPL465FyR4NKwpCsiV2DQIlwWkdeN2lZBzM
# [youtube:tab] Extracting URL: https://music.youtube.com/playlist?list=PL465FyR4NKwpCsiV2DQIlwWkdeN2lZBzM
# WARNING: [youtube:tab] YouTube Music is not directly supported. Redirecting to https://www.youtube.com/playlist?list=PL465FyR4NKwpCsiV2DQIlwWkdeN2lZBzM
# [youtube:tab] PL465FyR4NKwpCsiV2DQIlwWkdeN2lZBzM: Downloading webpage
# [youtube:tab] PL465FyR4NKwpCsiV2DQIlwWkdeN2lZBzM: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: songs
# [youtube:tab] PL465FyR4NKwpCsiV2DQIlwWkdeN2lZBzM page 1: Downloading API JSON
# [youtube:tab] Playlist songs: Downloading 73 items of 73
# [download] Downloading item 1 of 73
# [youtube] Extracting URL: https://music.youtube.com/watch?v=LyGXvhsAJA0
# [youtube] LyGXvhsAJA0: Downloading webpage
# [youtube] LyGXvhsAJA0: Downloading ios player API JSON
# [youtube] LyGXvhsAJA0: Downloading android player API JSON
# ...

# %%
https://www.youtube.com/watch?v=XXYlFuWEuKI&list=PLMC9KNkIncKtPzgY-5rmhvj7fax8fdxoj
https://www.youtube.com/watch?v=Iq8h3GEe22o&list=PLDIoUOhQQPlXr63I_vwF9GD8sAKh77dWU
https://www.youtube.com/watch?v=vX2cDW8LUWk&list=PLO7-VO1D0_6NYoMAN0XncJu4tvibirSmN 
https://www.youtube.com/watch?v=cWMxCE2HTag&list=PLFFyMei_d85U5RQdXjRQ5F012qr4vSmSa

# %%
\

# %%
import os
import yt_dlp as youtube_dl
from googleapiclient.errors import HttpError
from googleapiclient.discovery import build
import pandas as pd

# Set up your YouTube Data API key
API_KEY = "AIzaSyD5h1myju5oxuNDA1XDUaIKy_piFUfEPIU"


def get_playlist_id(playlist_url):
    with youtube_dl.YoutubeDL() as ydl:
        info_dict = ydl.extract_info(playlist_url, download=False)
        return info_dict.get("id", "")


def get_video_ids_from_playlist(playlist_id, api_key):
    youtube = build("youtube", "v3", developerKey=api_key)
    request = youtube.playlistItems().list(
        part="contentDetails", playlistId=playlist_id, maxResults=50
    )
    response = request.execute()

    video_ids = [item["contentDetails"]["videoId"] for item in response["items"]]
    return video_ids


def youtube_video_info(video_id, api_key, playlist_url):
    youtube = build("youtube", "v3", developerKey=api_key)
    try:
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics", id=video_id
        )
        response = request.execute()

        video_info = {
            "title": response["items"][0]["snippet"]["title"]
            if "items" in response and response["items"]
            else "",
            "duration": response["items"][0]["contentDetails"]["duration"]
            if "items" in response and response["items"]
            else "",
            "views": int(response["items"][0]["statistics"]["viewCount"])
            if "items" in response and response["items"]
            else 0,
            "likes": int(response["items"][0]["statistics"]["likeCount"])
            if "items" in response and response["items"]
            else 0,
            "genre": response["items"][0]["snippet"]["categoryId"]
            if "items" in response and response["items"]
            else "",
            "upload_date": response["items"][0]["snippet"]["publishedAt"]
            if "items" in response and response["items"]
            else "",
            "url": f"https://www.youtube.com/watch?v={video_id}",  # Add video URL
            "playlist_url": playlist_url,  # Add playlist URL
            # Add more details as needed
        }

        return video_info
    except HttpError as e:
        # Handle HttpError (video not available)
        print(f"Video with ID {video_id} is not available. Skipping.")
        return None


def create_playlist_dataframe(video_ids, api_key, playlist_url):
    video_info_list = []

    for video_id in video_ids:
        video_info = youtube_video_info(video_id, api_key, playlist_url)
        if video_info is not None:
            video_info_list.append(video_info)

    video_dataframe = pd.DataFrame(video_info_list)
    return video_dataframe

def main():
    # Example YouTube playlist URL
    youtube_playlist_url = "https://www.youtube.com/watch?v=vX2cDW8LUWk&list=PLO7-VO1D0_6NYoMAN0XncJu4tvibirSmN "

    # Set up your YouTube Data API key
    api_key = "AIzaSyD5h1myju5oxuNDA1XDUaIKy_piFUfEPIU"

    # Get playlist ID and video IDs
    playlist_id = get_playlist_id(youtube_playlist_url)
    video_ids = get_video_ids_from_playlist(playlist_id, api_key)

    # Create a DataFrame with extracted features for the playlist videos
    playlist_dataframe = create_playlist_dataframe(video_ids, api_key, youtube_playlist_url)

    # Display the DataFrame
    print("\nDataFrame:")
    print(playlist_dataframe)

    # Save the DataFrame to a CSV file
    csv_file_path = "playlist_videos_new6.csv"
    playlist_dataframe.to_csv(csv_file_path, index=False)
    print(f"\nDataFrame saved to {csv_file_path}")


main()
# Out:
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=cWMxCE2HTag&list=PLFFyMei_d85U5RQdXjRQ5F012qr4vSmSa
# [youtube:tab] Downloading playlist PLFFyMei_d85U5RQdXjRQ5F012qr4vSmSa - add --no-playlist to download just the video cWMxCE2HTag
# [youtube:tab] PLFFyMei_d85U5RQdXjRQ5F012qr4vSmSa: Downloading webpage
# [youtube:tab] Extracting URL: https://www.youtube.com/playlist?list=PLFFyMei_d85U5RQdXjRQ5F012qr4vSmSa
# [youtube:tab] PLFFyMei_d85U5RQdXjRQ5F012qr4vSmSa: Downloading webpage
# WARNING: [youtube:tab] YouTube said: INFO - Unavailable videos are hidden
# [youtube:tab] PLFFyMei_d85U5RQdXjRQ5F012qr4vSmSa: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: Top Punjabi Songs 2024 Best Collection Ever
# [youtube:tab] PLFFyMei_d85U5RQdXjRQ5F012qr4vSmSa page 1: Downloading API JSON
# [youtube:tab] PLFFyMei_d85U5RQdXjRQ5F012qr4vSmSa page 2: Downloading API JSON
# [youtube:tab] PLFFyMei_d85U5RQdXjRQ5F012qr4vSmSa page 3: Downloading API JSON
# ...

# %%
import os
import yt_dlp as youtube_dl
from googleapiclient.errors import HttpError
from googleapiclient.discovery import build
import pandas as pd

# Set up your YouTube Data API key
API_KEY = "AIzaSyD5h1myju5oxuNDA1XDUaIKy_piFUfEPIU"


def get_playlist_id(playlist_url):
    with youtube_dl.YoutubeDL() as ydl:
        info_dict = ydl.extract_info(playlist_url, download=False)
        return info_dict.get("id", "")


def get_video_ids_from_playlist(playlist_id, api_key):
    youtube = build("youtube", "v3", developerKey=api_key)
    request = youtube.playlistItems().list(
        part="contentDetails", playlistId=playlist_id, maxResults=50
    )
    response = request.execute()

    video_ids = [item["contentDetails"]["videoId"] for item in response["items"]]
    return video_ids


def youtube_video_info(video_id, api_key, playlist_url):
    youtube = build("youtube", "v3", developerKey=api_key)
    try:
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics", id=video_id
        )
        response = request.execute()

        video_info = {
            "title": response["items"][0]["snippet"]["title"]
            if "items" in response and response["items"]
            else "",
            "duration": response["items"][0]["contentDetails"]["duration"]
            if "items" in response and response["items"]
            else "",
            "views": int(response["items"][0]["statistics"]["viewCount"])
            if "items" in response and response["items"]
            else 0,
            "likes": int(response["items"][0]["statistics"]["likeCount"])
            if "items" in response and response["items"]
            else 0,
            "genre": response["items"][0]["snippet"]["categoryId"]
            if "items" in response and response["items"]
            else "",
            "upload_date": response["items"][0]["snippet"]["publishedAt"]
            if "items" in response and response["items"]
            else "",
            "url": f"https://www.youtube.com/watch?v={video_id}",  # Add video URL
            "playlist_url": playlist_url,  # Add playlist URL
            # Add more details as needed
        }

        return video_info
    except HttpError as e:
        # Handle HttpError
        if "The uploader has not made this video available in your country" in str(e):
            print(f"Video with ID {video_id} is not available in your country. Skipping.")
            return None  # Skip the video not available in the country
        elif e.resp.status == 404:
            print(f"Video with ID {video_id} is not available. Skipping.")
            return None  # Skip the unavailable video
        elif "Private video" in str(e):
            print(f"Video with ID {video_id} is private. Skipping.")
            return None  # Skip the private video
        else:
            print(f"An error occurred while processing video with ID {video_id}: {e}")
            return None
    except Exception as e:
        # Handle any other exceptions
        print(f"An unexpected error occurred while processing video with ID {video_id}: {e}")
        return None


def create_playlist_dataframe(video_ids, api_key, playlist_url):
    video_info_list = []

    for video_id in video_ids:
        video_info = youtube_video_info(video_id, api_key, playlist_url)
        if video_info is not None:
            video_info_list.append(video_info)

    video_dataframe = pd.DataFrame(video_info_list)
    return video_dataframe

def main():
    # Example YouTube playlist URL
    youtube_playlist_url = "https://music.youtube.com/watch?v=H4nyLuecbi0&list=RDATfgcHVuamFiaQ"

    # Set up your YouTube Data API key
    api_key = "AIzaSyD5h1myju5oxuNDA1XDUaIKy_piFUfEPIU"

    # Get playlist ID and video IDs
    playlist_id = get_playlist_id(youtube_playlist_url)
    video_ids = get_video_ids_from_playlist(playlist_id, api_key)

    # Create a DataFrame with extracted features for the playlist videos
    playlist_dataframe = create_playlist_dataframe(video_ids, api_key, youtube_playlist_url)

    # Display the DataFrame
    print("\nDataFrame:")
    print(playlist_dataframe)

    # Save the DataFrame to a CSV file
    csv_file_path = "playlist_videos_new6.csv"
    playlist_dataframe.to_csv(csv_file_path, index=False)
    print(f"\nDataFrame saved to {csv_file_path}")


main()
# Out:
# [youtube:tab] Extracting URL: https://music.youtube.com/watch?v=H4nyLuecbi0&list=RDATfgcHVuamFiaQ
# WARNING: [youtube:tab] YouTube Music is not directly supported. Redirecting to https://www.youtube.com/watch?v=H4nyLuecbi0&list=RDATfgcHVuamFiaQ
# [youtube:tab] Downloading playlist RDATfgcHVuamFiaQ - add --no-playlist to download just the video H4nyLuecbi0
# [youtube:tab] RDATfgcHVuamFiaQ: Downloading webpage
# [download] Downloading playlist: Radio • Punjabi
# [youtube:tab] RDATfgcHVuamFiaQ page 1: Downloading API JSON
# [youtube:tab] RDATfgcHVuamFiaQ page 2: Downloading API JSON
# [youtube:tab] RDATfgcHVuamFiaQ page 3: Downloading API JSON
# [youtube:tab] RDATfgcHVuamFiaQ page 4: Downloading API JSON
# [youtube:tab] RDATfgcHVuamFiaQ page 5: Downloading API JSON
# [youtube:tab] RDATfgcHVuamFiaQ page 6: Downloading API JSON
# [youtube:tab] RDATfgcHVuamFiaQ page 7: Downloading API JSON
# [youtube:tab] Playlist Radio • Punjabi: Downloading 159 items of 159
# ...
